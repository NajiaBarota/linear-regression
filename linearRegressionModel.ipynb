# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from sklearn import linear_model 
df= pd.read_csv('D:\\Training_works\\pythonCodes\\linear_regression\\video.csv')
df
# Out:
#          Date  VidStreamDownload  VidStreamStartdelay
# 0   23-Jul-21            1340.52                 4281
# 1   24-Jul-21            1358.94                 4288
# 2   25-Jul-21            1352.10                 4266
# 3   26-Jul-21            1429.12                 4097
# 4   27-Jul-21            1439.70                 4074
# 5   28-Jul-21            1432.70                 4031
# 6   29-Jul-21            1441.02                 4015
# 7   30-Jul-21            1441.99                 4046
# 8   31-Jul-21            1470.91                 3933
# 9   01-Aug-21            1511.40                 3816
# 10  02-Aug-21            1536.50                 3755
# 11  03-Aug-21            1361.42                 4027
# 12  04-Aug-21            1223.59                 4507
# 13  05-Aug-21            1568.33                 3712
# 14  06-Aug-21            1275.92                 4235
# 15  07-Aug-21            1318.83                 4050
# ...

# %%
# %matplotlib inline


plt.xlabel('VidStreamStartdelay')
plt.ylabel('VidStreamDownload')
plt.scatter(df.VidStreamStartdelay,df.VidStreamDownload)
plt.plot(df.VidStreamStartdelay,reg.predict(df[['VidStreamStartdelay']]))

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['VidStreamStartdelay']],df.VidStreamDownload)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-0.42177847])

# %%
reg.intercept_
# Out:
# 3106.673210315681

# %%
reg.score(df[['VidStreamStartdelay']],df.VidStreamDownload)
# Out:
# 0.9338993576043133
